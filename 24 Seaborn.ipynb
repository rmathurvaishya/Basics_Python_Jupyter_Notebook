# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x='timepoint',y='signal',data=fmri,)
plt.show()

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
#"hue" ne diff lines bna de acoording to stim & cue in x='timepoint',y='signal'.
sns.lineplot(x='timepoint',y='signal',data=fmri,hue='event')
plt.show()

# %%
sns.lineplot(x="timepoint",y='signal',data=fmri,hue= 'event',style='event')
plt.show()

# %% [markdown]
# ### Marker

# %%
sns.set(style="dark")
sns.lineplot(x="timepoint",y='signal',data=fmri,hue= 'event',style='event',markers=True)
plt.show()

# %% [markdown]
# ### Bar_Plot

# %%
pokemon = pd.read_csv("D:\PYTHON TUTORIAL VIDEOS\start\iris\pokemon.csv")

# %%
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
sns.set(style="darkgrid")
sns.barplot(x="is_legendary",y='speed',data=pokemon,)
plt.show()

# %%
sns.set(style="darkgrid")
sns.barplot(x="is_legendary",y='speed',data=pokemon,palette='Blues_d')
plt.show()

# %%
sns.set(style="whitegrid")
sns.barplot(x="is_legendary",y='speed',data=pokemon,color='orange',)
plt.show()

# %%
sns.set(style="whitegrid")
sns.barplot(x="is_legendary",y='speed',data=pokemon,palette=("BrBG"))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set(style="whitegrid")
sns.barplot(x='is_legendary',y='speed',hue='generation',data = pokemon)
plt.show()

# %% [markdown]
# ## Scatter_Plot

# %%
iris = pd.read_csv("D:\PYTHON TUTORIAL VIDEOS\start\iris\iris.csv")
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
plt.figure(figsize=(8,8))
sns.set(style="whitegrid")
sns.scatterplot(x ='sepal.length',y ='petal.length',data = iris,hue='petal.length')
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.set(style="darkgrid")
sns.scatterplot(x ='sepal.length',y ='petal.length',data = iris,hue='variety',style='variety')
plt.show()

# %% [markdown]
# ### Histogram/Distplot

# %%
diamonds = sns.load_dataset('diamonds')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
plt.figure(figsize=(8,8))
sns.distplot(diamonds['price'],hist=False,color='red')
plt.show()
# Out:
# C:\Users\91942\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,8))
sns.histplot(diamonds['price'],kde=True,color='green')  #kde=False pe curve line nhi aege
plt.show()

# %%
sns.displot(diamonds['price'],bins=11,)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds = sns.load_dataset('diamonds')

# %%
plt.figure(figsize=(8,8))
sns.histplot(data=diamonds,y='price',bins=10)
plt.show()

# %% [markdown]
# ### Joint_Plot

# %%
iris = pd.read_csv("D:\PYTHON TUTORIAL VIDEOS\start\iris\iris.csv")

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.jointplot(x="sepal.length",y="petal.length",data=iris,color="olive",kind='reg')
plt.show()

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %% [markdown]
# ### Box_Plot

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.set(style="darkgrid")
ax = sns.boxplot(x="day", y="total_bill", #hue="smoker",
                 data=tips, palette="Set3")

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="time",
                 data=tips, linewidth=2.5)

# %%
ax = sns.boxplot(x="time", y="tip", data=tips,
                 order=["Dinner", "Lunch",])

# %% [markdown]
# ### Pair_Plot

# %%
iris = pd.read_csv("D:\PYTHON TUTORIAL VIDEOS\start\iris\iris.csv")

# %%
sns.pairplot(data=iris,hue='variety')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
